# %%
import os
import joblib
import pandas as pd
from interpret import show
import plotly.io as pio

pio.renderers.default = "notebook"  # or "inline", "jupyterlab", etc.

# %%
INPUT_DIR = "ebm_inputs"
MODEL_DIR = "models"
OUT_DIR_SHAPES = os.path.join(MODEL_DIR, "plots\shape_plots")
OUT_DIR_SUMMARY = os.path.join(MODEL_DIR, "plots\summary_plots")

os.makedirs(OUT_DIR_SHAPES, exist_ok=True)
os.makedirs(OUT_DIR_SUMMARY, exist_ok=True)

sexes = ["M", "F"]
TOP_K = 15  # number of feature-wise shape plots per model to save

# Base datasets we trained from
base_variants = {
    "tnpca": os.path.join(INPUT_DIR, "ebm_input_tnpca.csv"),
    "vae":   os.path.join(INPUT_DIR, "ebm_input_vae.csv"),
    "pca":   os.path.join(INPUT_DIR, "ebm_input_pca.csv"),
}

# For each base dataset, which model variants exist?
# These must match what ebm_alcohol.py trains/saves.
model_variants_by_base = {
    "tnpca": ["tnpca", "cog_only", "tnpca_only"],
    "vae":   ["vae", "vae_only"],
    "pca":   ["pca", "pca_only"],
}

def load_model(model_path):
    obj = joblib.load(model_path)
    if isinstance(obj, dict):
        return obj["model"], obj.get("features", None)
    else:
        return obj, None

# %%
for base_variant, data_path in base_variants.items():
    if not os.path.exists(data_path):
        print(f"[WARN] missing {data_path}, skipping base_variant={base_variant}")
        continue

    df = pd.read_csv(data_path)

    if "Gender" not in df.columns or "alc_y" not in df.columns:
        raise ValueError(f"'Gender' or 'alc_y' missing in {data_path}")

    model_variants = model_variants_by_base[base_variant]

    for sex in sexes:
        df_sex = df[df["Gender"] == sex].copy()
        if df_sex.empty:
            print(f"[INFO] no rows for sex={sex}, base_variant={base_variant}, skipping")
            continue

        pos_rate = df_sex["alc_y"].mean()
        print(f"\n=== sex={sex}, base_variant={base_variant} (pos rate={pos_rate:.3f}) ===")

        for variant in model_variants:
            model_path = os.path.join(MODEL_DIR, f"ebm_{sex}_{variant}.pkl")
            if not os.path.exists(model_path):
                print(f"  [WARN] missing model {model_path}, skipping variant={variant}")
                continue

            print(f"  -> plots for model variant={variant}")

            ebm, feat_list = load_model(model_path)

            # Global explanation
            global_expl = ebm.explain_global(name=f"{sex}-{variant}")

            # ----- 1) Summary / coverage plot (feature importance) -----
            summary_fig = global_expl.visualize()   # overview bar chart
            summary_fig.update_layout(
                title=f"{sex} - {variant} - Feature importance summary",
                margin=dict(l=80, r=20, t=60, b=50),
            )

            summary_path = os.path.join(
                OUT_DIR_SUMMARY, f"summary_{sex}_{variant}.png"
            )
            summary_fig.write_image(summary_path, width=900, height=700, scale=2)
            print("     saved summary plot:", summary_path)

            # ----- 2) Top-K shape plots -----
            data_all = global_expl.data()
            term_names = data_all["names"]
            n_terms = len(term_names)
            print("     number of terms:", n_terms)

            K = min(TOP_K, n_terms)

            for idx in range(K):
                name = term_names[idx]
                safe_name = str(name).replace(" ", "_").replace("/", "_")

                fig = global_expl.visualize(idx)
                fig.update_layout(
                    title=f"{sex} - {variant} - {name}",
                    margin=dict(l=50, r=20, t=60, b=50),
                )

                out_path = os.path.join(
                    OUT_DIR_SHAPES,
                    f"shape_{sex}_{variant}_{idx:02d}_{safe_name}.png"
                )
                fig.write_image(out_path, width=800, height=600, scale=2)
                print("       saved shape plot:", out_path)
# Out:
# === sex=M, base_variant=tnpca (pos rate=0.195) ===
#   -> plots for model variant=tnpca
#      saved summary plot: models\plots\summary_plots\summary_M_tnpca.png
#      number of terms: 86
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_00_Age_in_Yrs.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_01_PMAT24_A_CR.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_02_PMAT24_A_SI.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_03_PMAT24_A_RTCR.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_04_ReadEng_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_05_ReadEng_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_06_PicVocab_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_07_PicVocab_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_08_IWRD_TOT.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_09_IWRD_RTC.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_10_ProcSpeed_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_11_ProcSpeed_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_12_DDisc_SV_1mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_13_DDisc_SV_6mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_14_DDisc_SV_1yr_200.png
#   -> plots for model variant=cog_only
#      saved summary plot: models\plots\summary_plots\summary_M_cog_only.png
#      number of terms: 46
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_00_Age_in_Yrs.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_01_PMAT24_A_CR.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_02_PMAT24_A_SI.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_03_PMAT24_A_RTCR.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_04_ReadEng_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_05_ReadEng_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_06_PicVocab_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_07_PicVocab_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_08_IWRD_TOT.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_09_IWRD_RTC.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_10_ProcSpeed_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_11_ProcSpeed_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_12_DDisc_SV_1mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_13_DDisc_SV_6mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_M_cog_only_14_DDisc_SV_1yr_200.png
#   -> plots for model variant=tnpca_only
#      saved summary plot: models\plots\summary_plots\summary_M_tnpca_only.png
#      number of terms: 40
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_00_Struct_PC45.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_01_Struct_PC14.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_02_Struct_PC2.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_03_Struct_PC1.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_04_Func_PC18.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_05_Struct_PC35.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_06_Struct_PC44.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_07_Func_PC33.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_08_Func_PC20.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_09_Struct_PC15.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_10_Struct_PC33.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_11_Func_PC26.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_12_Func_PC7.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_13_Func_PC58.png
#        saved shape plot: models\plots\shape_plots\shape_M_tnpca_only_14_Struct_PC27.png
#
# === sex=F, base_variant=tnpca (pos rate=0.112) ===
#   -> plots for model variant=tnpca
#      saved summary plot: models\plots\summary_plots\summary_F_tnpca.png
#      number of terms: 86
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_00_Age_in_Yrs.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_01_PMAT24_A_CR.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_02_PMAT24_A_SI.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_03_PMAT24_A_RTCR.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_04_ReadEng_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_05_ReadEng_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_06_PicVocab_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_07_PicVocab_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_08_IWRD_TOT.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_09_IWRD_RTC.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_10_ProcSpeed_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_11_ProcSpeed_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_12_DDisc_SV_1mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_13_DDisc_SV_6mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_14_DDisc_SV_1yr_200.png
#   -> plots for model variant=cog_only
#      saved summary plot: models\plots\summary_plots\summary_F_cog_only.png
#      number of terms: 46
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_00_Age_in_Yrs.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_01_PMAT24_A_CR.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_02_PMAT24_A_SI.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_03_PMAT24_A_RTCR.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_04_ReadEng_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_05_ReadEng_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_06_PicVocab_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_07_PicVocab_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_08_IWRD_TOT.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_09_IWRD_RTC.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_10_ProcSpeed_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_11_ProcSpeed_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_12_DDisc_SV_1mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_13_DDisc_SV_6mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_F_cog_only_14_DDisc_SV_1yr_200.png
#   -> plots for model variant=tnpca_only
#      saved summary plot: models\plots\summary_plots\summary_F_tnpca_only.png
#      number of terms: 40
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_00_Func_PC26.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_01_Struct_PC60.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_02_Func_PC49.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_03_Func_PC53.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_04_Struct_PC13.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_05_Func_PC60.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_06_Struct_PC58.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_07_Func_PC14.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_08_Func_PC25.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_09_Func_PC41.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_10_Func_PC30.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_11_Func_PC37.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_12_Struct_PC10.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_13_Struct_PC54.png
#        saved shape plot: models\plots\shape_plots\shape_F_tnpca_only_14_Func_PC27.png
#
# === sex=M, base_variant=vae (pos rate=0.195) ===
#   -> plots for model variant=vae
#      saved summary plot: models\plots\summary_plots\summary_M_vae.png
#      number of terms: 86
#        saved shape plot: models\plots\shape_plots\shape_M_vae_00_Age_in_Yrs.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_01_PMAT24_A_CR.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_02_PMAT24_A_SI.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_03_PMAT24_A_RTCR.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_04_ReadEng_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_05_ReadEng_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_06_PicVocab_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_07_PicVocab_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_08_IWRD_TOT.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_09_IWRD_RTC.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_10_ProcSpeed_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_11_ProcSpeed_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_12_DDisc_SV_1mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_13_DDisc_SV_6mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_14_DDisc_SV_1yr_200.png
#   -> plots for model variant=vae_only
#      saved summary plot: models\plots\summary_plots\summary_M_vae_only.png
#      number of terms: 40
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_00_VAE_Func_LD47.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_01_VAE_Struct_LD38.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_02_VAE_Func_LD30.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_03_VAE_Func_LD14.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_04_VAE_Struct_LD1.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_05_VAE_Func_LD44.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_06_VAE_Struct_LD42.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_07_VAE_Func_LD4.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_08_VAE_Struct_LD47.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_09_VAE_Func_LD33.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_10_VAE_Func_LD49.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_11_VAE_Func_LD31.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_12_VAE_Func_LD60.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_13_VAE_Func_LD32.png
#        saved shape plot: models\plots\shape_plots\shape_M_vae_only_14_VAE_Func_LD40.png
#
# === sex=F, base_variant=vae (pos rate=0.112) ===
#   -> plots for model variant=vae
#      saved summary plot: models\plots\summary_plots\summary_F_vae.png
#      number of terms: 86
#        saved shape plot: models\plots\shape_plots\shape_F_vae_00_Age_in_Yrs.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_01_PMAT24_A_CR.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_02_PMAT24_A_SI.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_03_PMAT24_A_RTCR.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_04_ReadEng_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_05_ReadEng_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_06_PicVocab_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_07_PicVocab_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_08_IWRD_TOT.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_09_IWRD_RTC.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_10_ProcSpeed_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_11_ProcSpeed_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_12_DDisc_SV_1mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_13_DDisc_SV_6mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_14_DDisc_SV_1yr_200.png
#   -> plots for model variant=vae_only
#      saved summary plot: models\plots\summary_plots\summary_F_vae_only.png
#      number of terms: 40
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_00_VAE_Func_LD60.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_01_VAE_Struct_LD14.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_02_VAE_Struct_LD34.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_03_VAE_Func_LD3.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_04_VAE_Struct_LD2.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_05_VAE_Func_LD59.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_06_VAE_Struct_LD25.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_07_VAE_Func_LD50.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_08_VAE_Struct_LD35.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_09_VAE_Func_LD27.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_10_VAE_Struct_LD26.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_11_VAE_Func_LD39.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_12_VAE_Func_LD8.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_13_VAE_Func_LD21.png
#        saved shape plot: models\plots\shape_plots\shape_F_vae_only_14_VAE_Struct_LD18.png
#
# === sex=M, base_variant=pca (pos rate=0.195) ===
#   -> plots for model variant=pca
#      saved summary plot: models\plots\summary_plots\summary_M_pca.png
#      number of terms: 86
#        saved shape plot: models\plots\shape_plots\shape_M_pca_00_Age_in_Yrs.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_01_PMAT24_A_CR.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_02_PMAT24_A_SI.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_03_PMAT24_A_RTCR.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_04_ReadEng_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_05_ReadEng_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_06_PicVocab_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_07_PicVocab_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_08_IWRD_TOT.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_09_IWRD_RTC.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_10_ProcSpeed_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_11_ProcSpeed_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_12_DDisc_SV_1mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_13_DDisc_SV_6mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_14_DDisc_SV_1yr_200.png
#   -> plots for model variant=pca_only
#      saved summary plot: models\plots\summary_plots\summary_M_pca_only.png
#      number of terms: 40
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_00_Raw_Struct_PC29.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_01_Raw_Func_PC20.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_02_Raw_Struct_PC24.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_03_Raw_Func_PC24.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_04_Raw_Struct_PC48.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_05_Raw_Func_PC58.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_06_Raw_Func_PC18.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_07_Raw_Func_PC13.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_08_Raw_Struct_PC31.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_09_Raw_Func_PC47.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_10_Raw_Struct_PC60.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_11_Raw_Struct_PC26.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_12_Raw_Func_PC17.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_13_Raw_Func_PC54.png
#        saved shape plot: models\plots\shape_plots\shape_M_pca_only_14_Raw_Func_PC56.png
#
# === sex=F, base_variant=pca (pos rate=0.112) ===
#   -> plots for model variant=pca
#      saved summary plot: models\plots\summary_plots\summary_F_pca.png
#      number of terms: 86
#        saved shape plot: models\plots\shape_plots\shape_F_pca_00_Age_in_Yrs.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_01_PMAT24_A_CR.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_02_PMAT24_A_SI.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_03_PMAT24_A_RTCR.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_04_ReadEng_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_05_ReadEng_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_06_PicVocab_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_07_PicVocab_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_08_IWRD_TOT.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_09_IWRD_RTC.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_10_ProcSpeed_Unadj.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_11_ProcSpeed_AgeAdj.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_12_DDisc_SV_1mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_13_DDisc_SV_6mo_200.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_14_DDisc_SV_1yr_200.png
#   -> plots for model variant=pca_only
#      saved summary plot: models\plots\summary_plots\summary_F_pca_only.png
#      number of terms: 40
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_00_Raw_Func_PC22.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_01_Raw_Func_PC56.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_02_Raw_Func_PC59.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_03_Raw_Struct_PC49.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_04_Raw_Struct_PC56.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_05_Raw_Func_PC60.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_06_Raw_Struct_PC18.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_07_Raw_Struct_PC30.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_08_Raw_Func_PC39.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_09_Raw_Struct_PC24.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_10_Raw_Struct_PC57.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_11_Raw_Func_PC17.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_12_Raw_Func_PC49.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_13_Raw_Struct_PC44.png
#        saved shape plot: models\plots\shape_plots\shape_F_pca_only_14_Raw_Struct_PC25.png
